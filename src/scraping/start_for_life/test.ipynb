# %%
import pandas as pd
pd.read_csv("data/sitemap.csv")
# Out:
#                                                    URL  \
# 0    /start-for-life/baby/weaning/what-to-feed-your...
# 1     /start-for-life/toddler/activities-for-toddlers/
# 2    /start-for-life/baby/feeding-your-baby/breastf...
# 3    /start-for-life/pregnancy/week-by-week-guide-t...
# 4    /start-for-life/baby/baby-basics/newborn-and-b...
# ..                                                 ...
# 153  /start-for-life/pregnancy/week-by-week-guide-t...
# 154  /start-for-life/baby/feeding-your-baby/bottle-...
# 155  /start-for-life/pregnancy/week-by-week-guide-t...
# 156  /start-for-life/pregnancy/preparing-for-labour...
# 157  /start-for-life/baby/feeding-your-baby/bottle-...
#
#                                        Title
# 0                          Feeding on demand
# 1                       Caring for your baby
# 2                     Breastfeeding vitamins
# 3                 Storing and reheating food
# 4                            Baby basics hub
# ...
